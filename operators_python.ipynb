# %% [markdown]
# # operators in python
#
# ## python have 6 types of operators
# 1. arithematic operators
# 2. assignment operators
# 3. comparision operators
# 4. logical operators
# 5. membership operators
# 6. identity operators

# %%
 #arithematic operators- +,-,*,/,//,%
a=10
b=20
c=30
d=40
print(a+b)
print(b-d)
print(c*a)
print(d/b)
print(d//c)
# Out:
# 30
# -20
# 300
# 2.0
# 1

# %%
a1=100
b1=105
c1=93
d1=29
print(a1-d1)
print(a1+c1)
print(a1/b1)
print(b1//c1)
# Out:
# 71
# 193
# 0.9523809523809523
# 1

# %%
#assignment operators - +=,-=,*=,/=,//=,%=
a=10
a=a+10
print(a)
# Out:
# 20

# %%
a=10
a+=10
print(a)
# Out:
# 20

# %%
a=25
a-=50
print(a)
# Out:
# -25

# %%
a=44
a*=3
print(a)
# Out:
# 132

# %%
#comparision operators - >,<,>=,<=,==,!=(return true or false)
a=5
b=10
c=10
d=20
print(a>b)
print(b<c)
print(b>=c)
print(b==c)
print(b!=d)
# Out:
# False
# False
# True
# True
# True

# %%
#logical operator - and,or,not
# and - this operators checking all conditions are true result is true rest cases failed
# or - this operators check either one condition true true then result true rest cases failed
a=10
b=20
c=20
d=60
print(a>b and b==c)
print(a<b and c<d)
print(a>b or b==c)
print(a>b or b!=c)
print(
# Out:
# False
# True
# True
# False

# %%
# membership operators - checking members are present in that sequence or collection - in , not in 
names=["shiva","vikas","divya","alok"]
print("alok" in names )
print("chandra" in names)
print("Shiva" not in names)
print("Vikas" in names)
# Out:
# True
# False
# True
# False

# %%
# identity operators - memory identification of values - is, is not
a=10000
b=10000
print(id(a))
print(id(b))
print(a is b)
# Out:
# 1371997737424
# 1371997737744
# False

# %%
a=10
b=10
print(id(a))
print(id(b))
print(a is b)
# Out:
# 140735648068808
# 140735648068808
# True
